# %%
import pandas as pd
import numpy as np
import glob
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
all_data = pd.DataFrame()
for f in glob.glob("./RelatorioQualidadeAguasSuperficiais*.xlsx"):
    df = pd.read_excel(f)
    all_data = all_data.append(df,ignore_index=True)

# %%
all_data
# Out:
#       Período DE Período ATE  Cod_Interaguas    Tipo Rede            UGRHI  \
# 0     01/02/2011  01/02/2016             120  Rede Básica  06 - ALTO TIÊTE
# 1     01/02/2011  01/02/2016             120  Rede Básica  06 - ALTO TIÊTE
# 2     01/02/2011  01/02/2016             120  Rede Básica  06 - ALTO TIÊTE
# 3     01/02/2011  01/02/2016             120  Rede Básica  06 - ALTO TIÊTE
# 4     01/02/2011  01/02/2016             120  Rede Básica  06 - ALTO TIÊTE
# ...          ...         ...             ...          ...              ...
# 2528  22/04/2016  22/04/2021             120  Rede Básica  06 - ALTO TIÊTE
# 2529  22/04/2016  22/04/2021             120  Rede Básica  06 - ALTO TIÊTE
# 2530  22/04/2016  22/04/2021             120  Rede Básica  06 - ALTO TIÊTE
# 2531  22/04/2016  22/04/2021             120  Rede Básica  06 - ALTO TIÊTE
# 2532  22/04/2016  22/04/2021             120  Rede Básica  06 - ALTO TIÊTE
#
#      Código Ponto Status Ponto Data Coleta Hora Coleta  \
# 0       TAMT04900        Ativo  10/03/2011       09:55
# 1       TAMT04900        Ativo  19/05/2011       11:05
# 2       TAMT04900        Ativo  20/07/2011       09:40
# 3       TAMT04900        Ativo  01/09/2011       10:40
# 4       TAMT04900        Ativo  30/11/2011       11:20
# ...           ...          ...         ...         ...
# 2528    TAMT04900        Ativo  06/10/2020       15:12
# 2529    TAMT04900        Ativo  06/10/2020       15:12
# 2530    TAMT04900        Ativo  06/10/2020       15:12
# 2531    TAMT04900        Ativo  06/10/2020       15:12
# 2532    TAMT04900        Ativo  06/10/2020       15:12
#
#                               Parametro  ...    CLASSE  Município  UF  \
# 0                                    pH  ...  Classe 4  SÃO PAULO  SP
# 1                                    pH  ...  Classe 4  SÃO PAULO  SP
# 2                                    pH  ...  Classe 4  SÃO PAULO  SP
# 3                                    pH  ...  Classe 4  SÃO PAULO  SP
# 4                                    pH  ...  Classe 4  SÃO PAULO  SP
# ...                                 ...  ...       ...        ...  ..
# 2528             Chuvas nas últimas 24h  ...  Classe 4  SÃO PAULO  SP
# 2529                            Benzeno  ...  Classe 4  SÃO PAULO  SP
# 2530  Ens. Ecotoxic. c/ Vibrio fischeri  ...  Classe 4  SÃO PAULO  SP
# 2531             Carbono Orgânico Total  ...  Classe 4  SÃO PAULO  SP
# 2532                     Magnésio Total  ...  Classe 4  SÃO PAULO  SP
#
#      Inicio Operação Fim Operação   Latitude  Longitude Altitude  \
# 0         01/01/1977          NaN  23 31 36   46 37 56       700
# 1         01/01/1977          NaN  23 31 36   46 37 56       700
# 2         01/01/1977          NaN  23 31 36   46 37 56       700
# 3         01/01/1977          NaN  23 31 36   46 37 56       700
# 4         01/01/1977          NaN  23 31 36   46 37 56       700
# ...              ...          ...        ...        ...      ...
# 2528      01/01/1977          NaN  23 31 36   46 37 56       700
# 2529      01/01/1977          NaN  23 31 36   46 37 56       700
# 2530      01/01/1977          NaN  23 31 36   46 37 56       700
# 2531      01/01/1977          NaN  23 31 36   46 37 56       700
# 2532      01/01/1977          NaN  23 31 36   46 37 56       700
#
#                                             Localização Captação
# 0     Ponte na Av. Santos Dumont, em frente à Secret...        N
# 1     Ponte na Av. Santos Dumont, em frente à Secret...        N
# 2     Ponte na Av. Santos Dumont, em frente à Secret...        N
# 3     Ponte na Av. Santos Dumont, em frente à Secret...        N
# 4     Ponte na Av. Santos Dumont, em frente à Secret...        N
# ...                                                 ...      ...
# 2528  Ponte na Av. Santos Dumont, em frente à Secret...        N
# 2529  Ponte na Av. Santos Dumont, em frente à Secret...        N
# 2530  Ponte na Av. Santos Dumont, em frente à Secret...        N
# 2531  Ponte na Av. Santos Dumont, em frente à Secret...        N
# 2532  Ponte na Av. Santos Dumont, em frente à Secret...        N
#
# [2533 rows x 26 columns]

# %%
#all_data['Parametro'].value_counts()

# %%
clean_data = all_data.drop(columns=['Cod_Interaguas', 'Código Ponto', 'Status Ponto', 'Tipo Rede', 'Período DE', 'Período ATE', 'CLASSE', 'Inicio Operação', 'UF', 'Fim Operação', 'Latitude', 'Longitude', 'Captação', 'Localização', 'Município', 'Tipo de Sistema Hídrico', 'UGRHI', 'Sistema Hídrico', 'Altitude', 'Sinal'])
clean_data['Valor'] = clean_data['Valor'].str.replace(',','.')
res = clean_data[pd.to_numeric(clean_data['Valor'], errors='coerce').notnull()]
res1 = res.copy()
res1['Valor'] = res['Valor'].astype(float)

# %%
list_IQA = ['pH', 'Coliformes Termotolerantes', 'Fósforo Total', 'DBO (5, 20)', 'Oxigênio Dissolvido', 'Temperatura da Água', 'Nitrogênio Total', 'Fósforo Total', 'Turbidez', 'Sólido Total']
IQA_table = res1[res1['Parametro'].isin(list_IQA)]
IQA_sem_sol = ['pH', 'Fósforo Total', 'DBO (5, 20)', 'Oxigênio Dissolvido', 'Temperatura da Água', 'Nitrogênio Total', 'Fósforo Total', 'Turbidez']
SS_table = res1[res1['Parametro'].isin(IQA_sem_sol)]

# %%
pH_table = res1[res1["Parametro"] == 'pH']
coli_termo_table = res1[res1["Parametro"] == 'Coliformes Termotolerantes']
fosforo_table = res1[res1["Parametro"] == 'Fósforo Total']
O2_table = res1[res1["Parametro"] == 'Oxigênio Dissolvido']
turbidez_table = res1[res1["Parametro"] == 'Turbidez']
DBO_table = res1[res1["Parametro"] == 'DBO (5, 20)']
temp = res1[res1["Parametro"] == 'Temperatura da Água']
nit_total = res1[res1["Parametro"] == 'Nitrogênio Total']
fos_total = res1[res1["Parametro"] == 'Fósforo Total']
sol_total = res1[res1["Parametro"] == 'Sólido Total']

table_list = []
table_list.extend((pH_table, O2_table, turbidez_table, DBO_table))

# %%
with sns.axes_style("darkgrid"):
    fig, (ax1,ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9) = plt.subplots(9,1, figsize=(20, 20))

    ax1.set_title('pH')
    sns.lineplot(x='Data Coleta', y='Valor', data=pH_table, ax=ax1)

    ax2.set_title('Oxigênio Dissolvido')
    sns.lineplot(x='Data Coleta', y='Valor', data=O2_table, ax=ax2)

    ax3.set_title('Fósforo Total')
    sns.lineplot(x='Data Coleta', y='Valor', data=fosforo_table, ax=ax3)

    ax4.set_title('DBO (5, 20)')
    sns.lineplot(x='Data Coleta', y='Valor', data=DBO_table, ax=ax4)
    
    ax5.set_title('Temperatura da Água')
    sns.lineplot(x='Data Coleta', y='Valor', data=temp, ax=ax5)
    
    ax6.set_title('Nitrogênio Total')
    sns.lineplot(x='Data Coleta', y='Valor', data=nit_total, ax=ax6)
    
    ax7.set_title('Fósforo Total')
    sns.lineplot(x='Data Coleta', y='Valor', data=fos_total, ax=ax7)
    
    ax8.set_title('Sólido Total')
    sns.lineplot(x='Data Coleta', y='Valor', data=sol_total, ax=ax8)
    
    ax9.set_title('Turbidez')
    sns.lineplot(x='Data Coleta', y='Valor', data=turbidez_table, ax=ax9)
            
    plt.gcf().autofmt_xdate()
    plt.show()

# %%
fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(111)
sns.lineplot(data=IQA_table, x="Data Coleta", y="Valor", hue="Parametro")
plt.gcf().autofmt_xdate()
#plt.savefig('todos_ind.png', dpi=300)
plt.show()

# %%
firstData = IQA_table[IQA_table["Data Coleta"] == '10/03/2011']
firstData1 = SS_table[SS_table["Data Coleta"] == '10/03/2011']
secondData = IQA_table[IQA_table["Data Coleta"] == '20/01/2016']
thirdData = IQA_table[IQA_table["Data Coleta"] == '27/02/2020']

# %%
firstData
# Out:
#      Data Coleta Hora Coleta            Parametro   Valor Unidade  \
# 0     10/03/2011       09:55                   pH    7.40    U.pH
# 30    10/03/2011       09:55  Temperatura da Água   23.60      ºC
# 288   10/03/2011       09:55             Turbidez   38.80     UNT
# 1014  10/03/2011       09:55  Oxigênio Dissolvido    0.21    mg/L
# 1044  10/03/2011       09:55          DBO (5, 20)   84.00    mg/L
# 1104  10/03/2011       09:55         Sólido Total  384.00    mg/L
# 1194  10/03/2011       09:55        Fósforo Total    2.21    mg/L
#
#      Tipo Parâmetro
# 0       3- Químicos
# 30       2- Físicos
# 288      2- Físicos
# 1014    3- Químicos
# 1044    3- Químicos
# 1104     2- Físicos
# 1194    3- Químicos

# %%
secondData
# Out:
#      Data Coleta Hora Coleta            Parametro   Valor Unidade  \
# 29    20/01/2016       09:25                   pH    7.35    U.pH
# 59    20/01/2016       09:25  Temperatura da Água   22.70      ºC
# 317   20/01/2016       09:25             Turbidez    9.10     UNT
# 825   20/01/2016       09:25     Nitrogênio Total   25.60    mg/L
# 1043  20/01/2016       09:25  Oxigênio Dissolvido    0.21    mg/L
# 1073  20/01/2016       09:25          DBO (5, 20)   89.00    mg/L
# 1133  20/01/2016       09:25         Sólido Total  434.00    mg/L
# 1223  20/01/2016       09:25        Fósforo Total    2.68    mg/L
#
#      Tipo Parâmetro
# 29      3- Químicos
# 59       2- Físicos
# 317      2- Físicos
# 825     3- Químicos
# 1043    3- Químicos
# 1073    3- Químicos
# 1133     2- Físicos
# 1223    3- Químicos

# %%
thirdData
# Out:
#      Data Coleta Hora Coleta            Parametro   Valor Unidade  \
# 2390  27/02/2020       10:03                   pH    7.10    U.pH
# 2391  27/02/2020       10:03  Temperatura da Água   21.50      ºC
# 2395  27/02/2020       10:03  Oxigênio Dissolvido    4.25    mg/L
# 2414  27/02/2020       10:03             Turbidez   33.90     UNT
# 2418  27/02/2020       10:03          DBO (5, 20)    9.19    mg/L
# 2420  27/02/2020       10:03         Sólido Total  222.00    mg/L
# 2424  27/02/2020       10:03        Fósforo Total    0.47    mg/L
#
#      Tipo Parâmetro
# 2390    3- Químicos
# 2391     2- Físicos
# 2395    3- Químicos
# 2414     2- Físicos
# 2418    3- Químicos
# 2420     2- Físicos
# 2424    3- Químicos

# %%
fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(111)
sns.lineplot(data=coli_termo_table, x="Data Coleta", y="Valor", hue="Parametro")
plt.gcf().autofmt_xdate()
#plt.savefig('todos_ind.png', dpi=300)
plt.show()

# %%
with sns.axes_style("darkgrid"):
    fig, (ax1) = plt.subplots(1,1, figsize=(10,10))

    ax1.set_title('Índices IQA')
    sns.scatterplot(x='Parametro', y='Valor', hue="Parametro", data=firstData, ax=ax1, s=100)

# %% [markdown]
# ### Gráficos dos parâmetros do IQA
# <img src="Graficos.png">

# %% [markdown]
# ### Cálculo do IQA

# %%
# Out:
#      Data Coleta Hora Coleta                          Parametro  Valor  \
# 0     10/03/2011       09:55                                 pH   7.40
# 1     19/05/2011       11:05                                 pH   7.00
# 2     20/07/2011       09:40                                 pH   7.20
# 3     01/09/2011       10:40                                 pH   7.20
# 4     30/11/2011       11:20                                 pH   7.30
# ...          ...         ...                                ...    ...
# 2526  06/10/2020       15:12                       Chumbo Total   0.01
# 2529  06/10/2020       15:12                            Benzeno   2.50
# 2530  06/10/2020       15:12  Ens. Ecotoxic. c/ Vibrio fischeri   3.04
# 2531  06/10/2020       15:12             Carbono Orgânico Total  43.30
# 2532  06/10/2020       15:12                     Magnésio Total   4.00
#
#       Unidade                       Tipo Parâmetro
# 0        U.pH                          3- Químicos
# 1        U.pH                          3- Químicos
# 2        U.pH                          3- Químicos
# 3        U.pH                          3- Químicos
# 4        U.pH                          3- Químicos
# ...       ...                                  ...
# 2526     mg/L                          3- Químicos
# 2529     µg/L  Compostos Orgânicos Voláteis (COVs)
# 2530  EC20(%)                  6- Ecotoxicológicos
# 2531     mg/L                          3- Químicos
# 2532     mg/L                          3- Químicos
#
# [2421 rows x 6 columns]

# %%
w_O2 = 0.17
w_coli = 0.15
w_pH = 0.12
w_DBO = 0.10
w_temp = 0.10
w_nit = 0.10
w_fos = 0.10
w_turb = 0.08
w_res_tot = 0.08

# %%
coli_termo_table = res1[res1["Parametro"] == 'Coliformes Termotolerantes']
fosforo_table = res1[res1["Parametro"] == 'Fósforo Total']
O2_table = res1[res1["Parametro"] == 'Oxigênio Dissolvido']
turbidez_table = res1[res1["Parametro"] == 'Turbidez']
DBO_table = res1[res1["Parametro"] == 'DBO (5, 20)']
temp = res1[res1["Parametro"] == 'Temperatura da Água']
nit_total = res1[res1["Parametro"] == 'Nitrogênio Total']
fos_total = res1[res1["Parametro"] == 'Fósforo Total']
sol_total = res1[res1["Parametro"] == 'Sólido Total']
# Out:
# 7.1

# %%
coli = 3

# %% [markdown]
# ## IQA para ultima data (10/2020)

# %%
ph_ = pH_table.Valor.values[-1]
fosforo_=fosforo_table.Valor.values[-1]
o2_=O2_table.Valor.values[-1]
turbidez_=turbidez_table.Valor.values[-1]
DBO_=DBO_table.Valor.values[-1] ## 27/02/2020
delta_temp_ = temp.Valor.values[-1] -temp.Valor.values[-2] 
nit_=nit_total.Valor.values[-1] ## 27/03/2019
sol_=sol_total.Valor.values[-1]

# %% [markdown]
# ### Gráficos dos parâmetros do IQA do ultimo registro
# ##### Fosforo ( 06/10/2020)
# <img src="img/fosforo_2020.png">
#
# ##### PH ( 06/10/2020)
# <img src="img/ph_2020.png">
#
# ##### Oxigênio dissolvido  ( 06/10/2020)
# <img src="img/oxigenio_2020.png">
#
# ##### Turbidez  ( 06/10/2020)
# <img src="img/turbidez_2020.png">
#
# ##### DBO  ( 27/02/2020)
# <img src="img/dbo_2020.png">
#
# ##### Temperatura  (04/08/2020 - 06/10/2020)
# <img src="img/temperatura_2020.png">
#
# ##### Nitrogênio  (27/03/2019)
# <img src="img/nitrogenio_2019.png">
#
# ##### Residuos  ( 06/10/2020)
# <img src="img/residuo_2020.png">

# %% [markdown]
# ### Calculando IQA

# %%
fosforo_iqa = 15
ph_iqa =91
o2_iqa = 12
turbidez_iqa = 27
dbo_iqa = 35
temp_iqa = 32
nitrogenio_iqa = 37
residuo_iqa = 50
lista_iqa = [fosforo_iqa,w_fos,ph_iqa,w_pH,o2_iqa,w_O2,turbidez_iqa,w_turb,dbo_iqa,
             w_DBO,temp_iqa,w_temp,nitrogenio_iqa,w_nit,residuo_iqa,w_res_tot]

# %%
def calcula_iqa(lista_iqa):    
    i = 0
    IQA =1
    while i < len(lista_iqa):
        IQA *= lista_iqa[i]**lista_iqa[i+1]
        i+=2
    return IQA
calcula_iqa(lista_iqa)
# Out:
# 17.714283096369815

# %% [markdown]
# ### Sem nitrogênio (ultimo dado em 2019)

# %%
nitrogenio_iqa = 1
lista_iqa = [fosforo_iqa,w_fos,ph_iqa,w_pH,o2_iqa,w_O2,turbidez_iqa,w_turb,dbo_iqa,
             w_DBO,temp_iqa,w_temp,nitrogenio_iqa,1,residuo_iqa,w_res_tot]
calcula_iqa(lista_iqa)
# Out:
# 12.345350043765926
